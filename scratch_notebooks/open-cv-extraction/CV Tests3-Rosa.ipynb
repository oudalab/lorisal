# %%
## Start extract-figures.py code

import argparse
import json
import os
import sys

import cv2
import numpy

from image_mining.figure_extraction import FigureExtractor
from image_mining.utils import open_image

# %%
from IPython.display import Image, display
from IPython.core.display import HTML

PATH = "/home/eth/lorisal/lorisal/data/ouhsc/Rosa Vrsina/3/3254bbbb-c156-5e7c-adf8-15a7c7f9363c.jpg"
display(Image(filename = PATH, width=100, height=100))

# %%
params = {
"canny_threshold": 0, # No Luck Setting this at 1 or above
"erosion_element": "rectangle",
"erosion_size": 9, # Larger triggers more images
"dilation_element": "rectangle",
"dilation_size": 1, #Smaller Triggers more images
# "min_area": ,
# "min_height": ,
# "max_height": ,
# "min_width": ,
# "max_width": ,
}

INTERACTIVE = False
SAVE_JSON = False
output_dir = os.path.join(os.getcwd() + "/output/")
FILES = []
files_path = "/home/eth/lorisal/lorisal/data/ouhsc/Rosa Vrsina/3/"

for (dirpath, dirnames, filenames) in os.walk(files_path):
    FILES.extend(filenames)
    break

extractor = FigureExtractor(**params)

FILES.sort()

# print(output_dir)
# print(FILES)

# %%
if INTERACTIVE:
    display_images(extractor, FILES)
else:
    images_found = 0
    for f in FILES:
        try:
            base_name, source_image = open_image(files_path + f)
        except:
            print("Open Error for %s"%(f))
            continue

        output_base = os.path.join(output_dir, base_name)

#         print("Processing %s" % f)

        boxes = []

        for i, bbox in enumerate(extractor.find_figures(source_image), 1):
            extracted = source_image[bbox.image_slice]
            extract_filename = os.path.join(output_dir, "%s-%d.jpg" % (output_base, i))
            print("%s" % f, end=" ")
            cv2.imwrite(extract_filename, extracted)

            boxes.append(bbox.as_dict())
            display(Image(filename = extract_filename))
            images_found += 1
# Out:
# 06a861c2-fe34-5fdd-92d5-9003d8038621.jpg
# 0785dca7-ee1f-5c48-a710-207165a580e0.jpg
# 08c44f04-5664-5724-9225-b3685c5d6a83.jpg
# 0d898649-ac65-5739-b222-d666b5f86cd6.jpg
# 161f4531-949a-5734-866b-389f9b7e2a61.jpg
# 19822a9e-06af-5cd1-a820-6b41f73a93eb.jpg
# 1aabdad8-b83d-5c1c-93fb-85a4165fc74f.jpg
# 1d849748-7d93-57c4-99bb-35b567e93ed9.jpg
# 1e751c09-cc50-5f3f-b514-d03ca233f27c.jpg
# 1f448f5a-e693-536e-b68a-3b87ccf96e51.jpg
# 1fdbf253-6820-5c71-9792-a5fd1c70acc0.jpg
# 1fdbf253-6820-5c71-9792-a5fd1c70acc0.jpg
# 20fb7539-d0c6-5e5b-b3d0-b80a4b3a482d.jpg
# 20fb7539-d0c6-5e5b-b3d0-b80a4b3a482d.jpg
# 271f5dd4-a51a-5013-a02c-ac30d7ffa31a.jpg
# 2c55baee-7199-5702-9ad6-7805be785efd.jpg
# 30ab6f7c-4b68-5888-a0c3-d4c148557d95.jpg
# 30ab6f7c-4b68-5888-a0c3-d4c148557d95.jpg
# 36a87aca-81c3-5132-88df-6aa75683547d.jpg
# 3ab01139-195e-5e9f-b45a-63d05a9d69c2.jpg
# 3cdf06c4-c2fe-5846-94db-be7e7ca01c47.jpg
# 40d6b076-2679-5eda-99d5-8de16970473d.jpg
# 44bf5d46-20df-5407-9edd-e2c09871eef9.jpg
# 	Merging overlapping extracts: (47, 195)-(187, 345) (129, 247)-(263, 347)
# 47e90b6a-4618-5bd1-9d81-85b6de5e160a.jpg
# 49e44e7d-5f5b-5cad-b24a-f751b12013f3.jpg
# 5289b143-d154-57cd-85d0-fdc077d8d806.jpg
# 543c0485-ef33-5575-91e6-a6e4a1427808.jpg
# 543c0485-ef33-5575-91e6-a6e4a1427808.jpg
# 59416596-54ab-53ca-9b4b-47c05a55fc20.jpg
# 5a3da9fd-6826-55ae-9574-abbf64a6d2cd.jpg
# 5fb21ac1-f4ed-5a62-a708-fdc617491232.jpg
# 641535ee-0532-52d5-8128-d9bd0c50176d.jpg
# 641535ee-0532-52d5-8128-d9bd0c50176d.jpg
# 6c4e4ea9-1fc4-5349-aa65-0a17a1e7adff.jpg
# 6d1449ba-2134-5e26-aff0-6c686ef65907.jpg
# 	Merging overlapping extracts: (158, 363)-(262, 441) (60, 193)-(297, 404)
# 6d642f31-936e-5900-9803-4951be4fe3bf.jpg
# 74ea24de-a693-5240-8aa1-cc1ede2b8154.jpg
# 7637205d-0262-5671-8333-ea5b8ce77260.jpg
# 7ad41be0-807f-5e9c-8408-a2185c063b8e.jpg
# 	Merging overlapping extracts: (55, 109)-(265, 333) (48, 323)-(265, 447)
# 8fbf9e1f-02e5-5a77-a29e-740b7c0934e9.jpg
# 9502a8d6-d4c4-5959-b665-cda24570c659.jpg
# 9acf74d3-0538-5a1c-a15c-bd3816a285a9.jpg
# a6cc0b07-279a-5966-8bd6-232d2ed2326f.jpg
# ade895e1-7b5d-5bfe-b1fe-eea0e65ad49e.jpg
# ba419f6d-f1ec-53f7-832b-924b674609b1.jpg
# bd87d912-182c-5b1f-a9ea-77ebaf56f860.jpg
# c3339203-9b39-5d8c-86d9-3fc9802fffe9.jpg
# c37ead33-57c1-53a9-88b8-332fb3f1490e.jpg
# c87b0c87-e695-5dba-b77c-31dce15df020.jpg
# c9089260-edc5-5a63-bff2-6c2f8d84cb34.jpg
# ccae5734-f494-57f3-b307-db9561c6680f.jpg
# cd78a4e5-9453-529b-b44f-27ec5bfe9db7.jpg
# cda8cb55-4ff7-5ef9-88a7-bc08841e5c52.jpg
# d2a3562b-da1e-5405-ac21-da874e8d280d.jpg
# d2d32c9d-3a53-5176-8820-4e580ccdccd4.jpg
# d35ae3f3-e064-5c19-bf04-c8d77e5772be.jpg
# d64236d5-3d33-5c36-aaf7-cfd1295cfaf3.jpg
# 	Merging overlapping extracts: (79, 125)-(263, 340) (149, 47)-(286, 132)
# d929d4a5-c0ae-5b38-9edc-6e3bc7be2649.jpg
# e6a27e98-57c4-5b9c-8449-e72431597c4e.jpg
# ebcf0b72-ea17-5ae3-97af-f641595bdf9a.jpg
# ee3d4987-6a7e-5d1c-8788-0ff574bf6929.jpg

# %%
print("%d images found in %d pages"%(images_found, len(FILES)))
# Out:
# 94 images found in 917 pages

# %%
# Out:
# []
